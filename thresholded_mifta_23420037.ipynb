# %% [markdown]
# <a href="https://colab.research.google.com/github/Miftakhull/Thresholder/blob/main/thresholded_mifta_23420037.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
img_color = cv2.imread('gazania-flowers-rgb-beautiful-isolated-white-colors-55380608.jpg',1)
img = cv2.imread('gazania-flowers-rgb-beautiful-isolated-white-colors-55380608.jpg',0)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img_color) #tampilkan gambar uji coba, ternyata gambarnya tampil dengan format bgr
plt.axis("off")
plt.show()

# %%
plt.axis("off") #lalu kita ubah dari tampilan bgr ke rgb , agar terlihat seperti gambar semula
plt.imshow(cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Set thresholding value
threshold_value = 50

# %%
# Set maximum value
maximum_value = int(str(37)[-3:])  # Ubah "123456789" dengan NIM mahasiswa

# %%
# Apply thresholding
_, thresholded_image = cv2.threshold(img, threshold_value, maximum_value, cv2.THRESH_BINARY)

# %%
plt.axis("off") #tampilkan gambar ori format RGB
plt.imshow(cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(thresholded_image) #tampilan gambar setelah kita ubah thresholdernya
plt.axis("off")
plt.show()
